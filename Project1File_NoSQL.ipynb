# %%
# Creating NoSQL Database

# %%
# !pip install pymongo

# %%
import os
import datetime
import pymongo
import pprint
import pandas as pd

# %%
# Connect to local MongoDB Interface
host_name = "localhost"
port = "27017"

conn_str = {
    "local" : f"mongodb://{host_name}:{port}/"
}

client = pymongo.MongoClient(conn_str["local"])

print(f"Local Connection String: {conn_str['local']}")
# Out:
# Local Connection String: mongodb://localhost:27017/

# %%
# Create a new DB
db_name = "passengerflights"

db = client[db_name]
client.list_database_names()
# Out:
# ['TestMongo', 'admin', 'config', 'local', 'passengerflights']

# %%
# First flight info
flight =  {
    "FLIGHT_NUMBER": 1,
    "TAIL_NUMBER": "N837VA",
    "class": "Economy",
    "price": 159
  }

flights = db.flights
flight_id = flights.insert_one(flight).inserted_id

# %%
# Confirm that the DB is set up
print("Databases: ", client.list_database_names())
print("Collections: ", db.list_collection_names())
# Out:
# Databases:  ['TestMongo', 'admin', 'config', 'local', 'passengerflights']
# Collections:  ['flights']

# %%
flightdata = [
  {
    "FLIGHT_NUMBER": 2,
    "TAIL_NUMBER": "N633JB",
    "class": "Business",
    "price": 693
  },
  {
    "FLIGHT_NUMBER": 3,
    "TAIL_NUMBER": "N913JB",
    "class": "First",
    "price": 891
  },
  {
    "FLIGHT_NUMBER": 4,
    "TAIL_NUMBER": "N581AS",
    "class": "Economy",
    "price": 253
  },
  {
    "FLIGHT_NUMBER": 5,
    "TAIL_NUMBER": "N517AS",
    "class": "First",
    "price": 596
  },
  {
    "FLIGHT_NUMBER": 6,
    "TAIL_NUMBER": "N565AS",
    "class": "Economy",
    "price": 661
  },
  {
    "FLIGHT_NUMBER": 7,
    "TAIL_NUMBER": "N670SW",
    "class": "Economy",
    "price": 277
  },
  {
    "FLIGHT_NUMBER": 8,
    "TAIL_NUMBER": "N464AS",
    "class": "Business",
    "price": 844
  },
  {
    "FLIGHT_NUMBER": 9,
    "TAIL_NUMBER": "N792AA",
    "class": "Economy",
    "price": 516
  },
  {
    "FLIGHT_NUMBER": 10,
    "TAIL_NUMBER": "N389HA",
    "class": "Economy",
    "price": 498
  },
  {
    "FLIGHT_NUMBER": 11,
    "TAIL_NUMBER": "N384HA",
    "class": "Economy",
    "price": 310
  },
  {
    "FLIGHT_NUMBER": 12,
    "TAIL_NUMBER": "N842VA",
    "class": "Economy",
    "price": 508
  },
  {
    "FLIGHT_NUMBER": 14,
    "TAIL_NUMBER": "N823DN",
    "class": "Economy",
    "price": 255
  },
  {
    "FLIGHT_NUMBER": 15,
    "TAIL_NUMBER": "N944JB",
    "class": "Economy",
    "price": 622
  },
  {
    "FLIGHT_NUMBER": 16,
    "TAIL_NUMBER": "N934JB",
    "class": "Business",
    "price": 180
  },
  {
    "FLIGHT_NUMBER": 17,
    "TAIL_NUMBER": "N389HA",
    "class": "Business",
    "price": 699
  },
  {
    "FLIGHT_NUMBER": 18,
    "TAIL_NUMBER": "N373HA",
    "class": "First",
    "price": 671
  },
  {
    "FLIGHT_NUMBER": 19,
    "TAIL_NUMBER": "N749SW",
    "class": "Economy",
    "price": 202
  },
  {
    "FLIGHT_NUMBER": 20,
    "TAIL_NUMBER": "N7734H",
    "class": "Economy",
    "price": 434
  },
  {
    "FLIGHT_NUMBER": 21,
    "TAIL_NUMBER": "N373HA",
    "class": "Economy",
    "price": 677
  },
  {
    "FLIGHT_NUMBER": 22,
    "TAIL_NUMBER": "N521JB",
    "class": "Economy",
    "price": 816
  },
  {
    "FLIGHT_NUMBER": 23,
    "TAIL_NUMBER": "N937JB",
    "class": "Business",
    "price": 902
  },
  {
    "FLIGHT_NUMBER": 24,
    "TAIL_NUMBER": "N923JB",
    "class": "Economy",
    "price": 197
  },
  {
    "FLIGHT_NUMBER": 25,
    "TAIL_NUMBER": "N3AVAA",
    "class": "Economy",
    "price": 508
  },
  {
    "FLIGHT_NUMBER": 26,
    "TAIL_NUMBER": "N852VA",
    "class": "Economy",
    "price": 72
  },
  {
    "FLIGHT_NUMBER": 27,
    "TAIL_NUMBER": "N252WN",
    "class": "Economy",
    "price": 270
  },
  {
    "FLIGHT_NUMBER": 28,
    "TAIL_NUMBER": "N503JB",
    "class": "Business",
    "price": 455
  },
  {
    "FLIGHT_NUMBER": 29,
    "TAIL_NUMBER": "N370HA",
    "class": "First",
    "price": 880
  },
  {
    "FLIGHT_NUMBER": 30,
    "TAIL_NUMBER": "N514AS",
    "class": "Economy",
    "price": 75
  },
  {
    "FLIGHT_NUMBER": 31,
    "TAIL_NUMBER": "N5ESAA",
    "class": "First",
    "price": 969
  },
  {
    "FLIGHT_NUMBER": 32,
    "TAIL_NUMBER": "N747SA",
    "class": "Economy",
    "price": 888
  },
  {
    "FLIGHT_NUMBER": 33,
    "TAIL_NUMBER": "N385HA",
    "class": "Economy",
    "price": 843
  },
  {
    "FLIGHT_NUMBER": 34,
    "TAIL_NUMBER": "N413AS",
    "class": "Business",
    "price": 975
  },
  {
    "FLIGHT_NUMBER": 35,
    "TAIL_NUMBER": "N589HA",
    "class": "Economy",
    "price": 903
  },
  {
    "FLIGHT_NUMBER": 36,
    "TAIL_NUMBER": "N3EKAA",
    "class": "Economy",
    "price": 364
  },
  {
    "FLIGHT_NUMBER": 37,
    "TAIL_NUMBER": "N469AS",
    "class": "Economy",
    "price": 441
  },
  {
    "FLIGHT_NUMBER": 38,
    "TAIL_NUMBER": "N562AS",
    "class": "Economy",
    "price": 792
  },
  {
    "FLIGHT_NUMBER": 39,
    "TAIL_NUMBER": "N459AS",
    "class": "Economy",
    "price": 586
  },
  {
    "FLIGHT_NUMBER": 40,
    "TAIL_NUMBER": "N3BYAA",
    "class": "Economy",
    "price": 702
  },
  {
    "FLIGHT_NUMBER": 41,
    "TAIL_NUMBER": "N391HA",
    "class": "Business",
    "price": 336
  },
  {
    "FLIGHT_NUMBER": 42,
    "TAIL_NUMBER": "N3GPAA",
    "class": "Business",
    "price": 667
  },
  {
    "FLIGHT_NUMBER": 43,
    "TAIL_NUMBER": "N590HA",
    "class": "First",
    "price": 234
  },
  {
    "FLIGHT_NUMBER": 44,
    "TAIL_NUMBER": "N3AJAA",
    "class": "Economy",
    "price": 597
  },
  {
    "FLIGHT_NUMBER": 45,
    "TAIL_NUMBER": "N592HA",
    "class": "Economy",
    "price": 193
  },
  {
    "FLIGHT_NUMBER": 46,
    "TAIL_NUMBER": "N704X",
    "class": "Economy",
    "price": 967
  },
  {
    "FLIGHT_NUMBER": 47,
    "TAIL_NUMBER": "N583HA",
    "class": "Economy",
    "price": 875
  },
  {
    "FLIGHT_NUMBER": 48,
    "TAIL_NUMBER": "N3JXAA",
    "class": "Business",
    "price": 69
  },
  {
    "FLIGHT_NUMBER": 49,
    "TAIL_NUMBER": "N306JB",
    "class": "Economy",
    "price": 825
  },
  {
    "FLIGHT_NUMBER": 50,
    "TAIL_NUMBER": "N570AA",
    "class": "Economy",
    "price": 128
  },
  {
    "FLIGHT_NUMBER": 51,
    "TAIL_NUMBER": "N627JB",
    "class": "Economy",
    "price": 949
  },
  {
    "FLIGHT_NUMBER": 52,
    "TAIL_NUMBER": "N653JB",
    "class": "Business",
    "price": 586
  },
  {
    "FLIGHT_NUMBER": 53,
    "TAIL_NUMBER": "N3LHAA",
    "class": "Business",
    "price": 644
  },
  {
    "FLIGHT_NUMBER": 54,
    "TAIL_NUMBER": "N3CWAA",
    "class": "Business",
    "price": 265
  },
  {
    "FLIGHT_NUMBER": 55,
    "TAIL_NUMBER": "N508AS",
    "class": "Economy",
    "price": 596
  },
  {
    "FLIGHT_NUMBER": 56,
    "TAIL_NUMBER": "N190JB",
    "class": "Economy",
    "price": 280
  },
  {
    "FLIGHT_NUMBER": 57,
    "TAIL_NUMBER": "N348JB",
    "class": "Economy",
    "price": 902
  },
  {
    "FLIGHT_NUMBER": 58,
    "TAIL_NUMBER": "N5DFAA",
    "class": "Economy",
    "price": 857
  },
  {
    "FLIGHT_NUMBER": 59,
    "TAIL_NUMBER": "N5DFAA",
    "class": "Economy",
    "price": 649
  },
  {
    "FLIGHT_NUMBER": 60,
    "TAIL_NUMBER": "N796AS",
    "class": "Economy",
    "price": 434
  },
  {
    "FLIGHT_NUMBER": 61,
    "TAIL_NUMBER": "N850AA",
    "class": "Economy",
    "price": 396
  },
  {
    "FLIGHT_NUMBER": 62,
    "TAIL_NUMBER": "N792AS",
    "class": "First",
    "price": 756
  },
  {
    "FLIGHT_NUMBER": 63,
    "TAIL_NUMBER": "N3ECAA",
    "class": "First",
    "price": 514
  },
  {
    "FLIGHT_NUMBER": 64,
    "TAIL_NUMBER": "N3HXAA",
    "class": "Economy",
    "price": 228
  },
  {
    "FLIGHT_NUMBER": 65,
    "TAIL_NUMBER": "N713AS",
    "class": "Economy",
    "price": 116
  },
  {
    "FLIGHT_NUMBER": 66,
    "TAIL_NUMBER": "N631AA",
    "class": "Economy",
    "price": 305
  },
  {
    "FLIGHT_NUMBER": 67,
    "TAIL_NUMBER": "N644AS",
    "class": "Business",
    "price": 667
  },
  {
    "FLIGHT_NUMBER": 68,
    "TAIL_NUMBER": "N5EGAA",
    "class": "Economy",
    "price": 860
  },
  {
    "FLIGHT_NUMBER": 69,
    "TAIL_NUMBER": "N636VA",
    "class": "Economy",
    "price": 354
  },
  {
    "FLIGHT_NUMBER": 70,
    "TAIL_NUMBER": "N228JB",
    "class": "Economy",
    "price": 365
  },
  {
    "FLIGHT_NUMBER": 71,
    "TAIL_NUMBER": "N3GHAA",
    "class": "Business",
    "price": 261
  },
  {
    "FLIGHT_NUMBER": 72,
    "TAIL_NUMBER": "N5EKAA",
    "class": "Business",
    "price": 269
  },
  {
    "FLIGHT_NUMBER": 73,
    "TAIL_NUMBER": "N799AS",
    "class": "Business",
    "price": 551
  },
  {
    "FLIGHT_NUMBER": 74,
    "TAIL_NUMBER": "N505AA",
    "class": "Economy",
    "price": 305
  },
  {
    "FLIGHT_NUMBER": 75,
    "TAIL_NUMBER": "N708AS",
    "class": "Economy",
    "price": 191
  },
  {
    "FLIGHT_NUMBER": 76,
    "TAIL_NUMBER": "N3HPAA",
    "class": "Economy",
    "price": 622
  },
  {
    "FLIGHT_NUMBER": 77,
    "TAIL_NUMBER": "N841VA",
    "class": "Economy",
    "price": 224
  },
  {
    "FLIGHT_NUMBER": 79,
    "TAIL_NUMBER": "N520AA",
    "class": "Economy",
    "price": 148
  },
  {
    "FLIGHT_NUMBER": 80,
    "TAIL_NUMBER": "N845MH",
    "class": "Economy",
    "price": 962
  },
  {
    "FLIGHT_NUMBER": 81,
    "TAIL_NUMBER": "N577AS",
    "class": "Economy",
    "price": 963
  },
  {
    "FLIGHT_NUMBER": 82,
    "TAIL_NUMBER": "N957AT",
    "class": "First",
    "price": 786
  },
  {
    "FLIGHT_NUMBER": 83,
    "TAIL_NUMBER": "N4XBAA",
    "class": "First",
    "price": 558
  },
  {
    "FLIGHT_NUMBER": 84,
    "TAIL_NUMBER": "N3AXAA",
    "class": "Business",
    "price": 497
  },
  {
    "FLIGHT_NUMBER": 85,
    "TAIL_NUMBER": "N764AS",
    "class": "Business",
    "price": 139
  },
  {
    "FLIGHT_NUMBER": 86,
    "TAIL_NUMBER": "N3GTAA",
    "class": "Economy",
    "price": 277
  },
  {
    "FLIGHT_NUMBER": 87,
    "TAIL_NUMBER": "N490AA",
    "class": "Economy",
    "price": 831
  },
  {
    "FLIGHT_NUMBER": 89,
    "TAIL_NUMBER": "N3KVAA",
    "class": "Economy",
    "price": 164
  },
  {
    "FLIGHT_NUMBER": 90,
    "TAIL_NUMBER": "N633VA",
    "class": "Economy",
    "price": 416
  },
  {
    "FLIGHT_NUMBER": 92,
    "TAIL_NUMBER": "N3KHAA",
    "class": "Economy",
    "price": 210
  },
  {
    "FLIGHT_NUMBER": 93,
    "TAIL_NUMBER": "N3HHAA",
    "class": "Economy",
    "price": 924
  },
  {
    "FLIGHT_NUMBER": 94,
    "TAIL_NUMBER": "N3ANAA",
    "class": "Economy",
    "price": 742
  },
  {
    "FLIGHT_NUMBER": 95,
    "TAIL_NUMBER": "N320US",
    "class": "First",
    "price": 649
  },
  {
    "FLIGHT_NUMBER": 96,
    "TAIL_NUMBER": "N553AA",
    "class": "First",
    "price": 260
  },
  {
    "FLIGHT_NUMBER": 97,
    "TAIL_NUMBER": "N3ENAA",
    "class": "Business",
    "price": 583
  },
  {
    "FLIGHT_NUMBER": 98,
    "TAIL_NUMBER": "N407AS",
    "class": "Business",
    "price": 60
  },
  {
    "FLIGHT_NUMBER": 99,
    "TAIL_NUMBER": "N274JB",
    "class": "Economy",
    "price": 907
  },
  {
    "FLIGHT_NUMBER": 100,
    "TAIL_NUMBER": "N594JB",
    "class": "Economy",
    "price": 412
  },
  {
    "FLIGHT_NUMBER": 101,
    "TAIL_NUMBER": "N492HA",
    "class": "Economy",
    "price": 943
  },
  {
    "FLIGHT_NUMBER": 102,
    "TAIL_NUMBER": "N492HA",
    "class": "Economy",
    "price": 154
  },
  {
    "FLIGHT_NUMBER": 103,
    "TAIL_NUMBER": "N616NK",
    "class": "Economy",
    "price": 680
  },
  {
    "FLIGHT_NUMBER": 104,
    "TAIL_NUMBER": "N477HA",
    "class": "Economy",
    "price": 716
  },
  {
    "FLIGHT_NUMBER": 105,
    "TAIL_NUMBER": "N440AS",
    "class": "Economy",
    "price": 741
  },
  {
    "FLIGHT_NUMBER": 106,
    "TAIL_NUMBER": "N768AS",
    "class": "First",
    "price": 259
  },
  {
    "FLIGHT_NUMBER": 107,
    "TAIL_NUMBER": "N476HA",
    "class": "First",
    "price": 499
  },
  {
    "FLIGHT_NUMBER": 108,
    "TAIL_NUMBER": "N309AS",
    "class": "Economy",
    "price": 502
  },
  {
    "FLIGHT_NUMBER": 109,
    "TAIL_NUMBER": "N556AS",
    "class": "Economy",
    "price": 786
  },
  {
    "FLIGHT_NUMBER": 110,
    "TAIL_NUMBER": "N206FR",
    "class": "Economy",
    "price": 731
  },
  {
    "FLIGHT_NUMBER": 111,
    "TAIL_NUMBER": "N522NK",
    "class": "Economy",
    "price": 273
  },
  {
    "FLIGHT_NUMBER": 112,
    "TAIL_NUMBER": "N527AS",
    "class": "Economy",
    "price": 173
  },
  {
    "FLIGHT_NUMBER": 113,
    "TAIL_NUMBER": "N486HA",
    "class": "First",
    "price": 824
  },
  {
    "FLIGHT_NUMBER": 114,
    "TAIL_NUMBER": "N303AS",
    "class": "First",
    "price": 394
  },
  {
    "FLIGHT_NUMBER": 115,
    "TAIL_NUMBER": "N3CTAA",
    "class": "Business",
    "price": 996
  },
  {
    "FLIGHT_NUMBER": 116,
    "TAIL_NUMBER": "N492HA",
    "class": "Business",
    "price": 419
  },
  {
    "FLIGHT_NUMBER": 117,
    "TAIL_NUMBER": "N933FR",
    "class": "Economy",
    "price": 916
  },
  {
    "FLIGHT_NUMBER": 118,
    "TAIL_NUMBER": "N788AA",
    "class": "Economy",
    "price": 649
  },
  {
    "FLIGHT_NUMBER": 119,
    "TAIL_NUMBER": "N271LV",
    "class": "Economy",
    "price": 89
  },
  {
    "FLIGHT_NUMBER": 120,
    "TAIL_NUMBER": "N491HA",
    "class": "Economy",
    "price": 426
  },
  {
    "FLIGHT_NUMBER": 121,
    "TAIL_NUMBER": "N635NK",
    "class": "Economy",
    "price": 971
  },
  {
    "FLIGHT_NUMBER": 122,
    "TAIL_NUMBER": "N413AS",
    "class": "Economy",
    "price": 693
  },
  {
    "FLIGHT_NUMBER": 123,
    "TAIL_NUMBER": "N476HA",
    "class": "Economy",
    "price": 889
  },
  {
    "FLIGHT_NUMBER": 124,
    "TAIL_NUMBER": "N593AS",
    "class": "Economy",
    "price": 57
  },
  {
    "FLIGHT_NUMBER": 125,
    "TAIL_NUMBER": "N358SW",
    "class": "Economy",
    "price": 205
  },
  {
    "FLIGHT_NUMBER": 126,
    "TAIL_NUMBER": "N256WN",
    "class": "First",
    "price": 99
  },
  {
    "FLIGHT_NUMBER": 127,
    "TAIL_NUMBER": "N3GHAA",
    "class": "First",
    "price": 686
  },
  {
    "FLIGHT_NUMBER": 128,
    "TAIL_NUMBER": "N731SA",
    "class": "Business",
    "price": 509
  },
  {
    "FLIGHT_NUMBER": 129,
    "TAIL_NUMBER": "N4WPAA",
    "class": "Business",
    "price": 869
  },
  {
    "FLIGHT_NUMBER": 130,
    "TAIL_NUMBER": "N457AS",
    "class": "Economy",
    "price": 198
  },
  {
    "FLIGHT_NUMBER": 131,
    "TAIL_NUMBER": "N528AS",
    "class": "Economy",
    "price": 545
  },
  {
    "FLIGHT_NUMBER": 132,
    "TAIL_NUMBER": "N483HA",
    "class": "Economy",
    "price": 301
  },
  {
    "FLIGHT_NUMBER": 133,
    "TAIL_NUMBER": "N951FR",
    "class": "Economy",
    "price": 818
  },
  {
    "FLIGHT_NUMBER": 134,
    "TAIL_NUMBER": "N464AS",
    "class": "Economy",
    "price": 154
  },
  {
    "FLIGHT_NUMBER": 135,
    "TAIL_NUMBER": "N527AS",
    "class": "Business",
    "price": 322
  },
  {
    "FLIGHT_NUMBER": 136,
    "TAIL_NUMBER": "N431AS",
    "class": "First",
    "price": 693
  },
  {
    "FLIGHT_NUMBER": 137,
    "TAIL_NUMBER": "N621SW",
    "class": "Economy",
    "price": 765
  },
  {
    "FLIGHT_NUMBER": 138,
    "TAIL_NUMBER": "N931FR",
    "class": "First",
    "price": 333
  },
  {
    "FLIGHT_NUMBER": 139,
    "TAIL_NUMBER": "N651SW",
    "class": "Economy",
    "price": 353
  },
  {
    "FLIGHT_NUMBER": 140,
    "TAIL_NUMBER": "N621AA",
    "class": "Economy",
    "price": 495
  },
  {
    "FLIGHT_NUMBER": 141,
    "TAIL_NUMBER": "N5EDAA",
    "class": "Business",
    "price": 86
  },
  {
    "FLIGHT_NUMBER": 142,
    "TAIL_NUMBER": "N489HA",
    "class": "Economy",
    "price": 547
  },
  {
    "FLIGHT_NUMBER": 143,
    "TAIL_NUMBER": "N480HA",
    "class": "Economy",
    "price": 705
  },
  {
    "FLIGHT_NUMBER": 144,
    "TAIL_NUMBER": "N514AS",
    "class": "Economy",
    "price": 347
  },
  {
    "FLIGHT_NUMBER": 145,
    "TAIL_NUMBER": "N76064",
    "class": "Economy",
    "price": 281
  },
  {
    "FLIGHT_NUMBER": 146,
    "TAIL_NUMBER": "N7741C",
    "class": "Economy",
    "price": 232
  },
  {
    "FLIGHT_NUMBER": 147,
    "TAIL_NUMBER": "N659JB",
    "class": "Economy",
    "price": 953
  },
  {
    "FLIGHT_NUMBER": 148,
    "TAIL_NUMBER": "N3EJAA",
    "class": "Business",
    "price": 829
  },
  {
    "FLIGHT_NUMBER": 149,
    "TAIL_NUMBER": "N298JB",
    "class": "Business",
    "price": 828
  },
  {
    "FLIGHT_NUMBER": 150,
    "TAIL_NUMBER": "N8642E",
    "class": "First",
    "price": 951
  },
  {
    "FLIGHT_NUMBER": 151,
    "TAIL_NUMBER": "N612NK",
    "class": "Economy",
    "price": 794
  },
  {
    "FLIGHT_NUMBER": 152,
    "TAIL_NUMBER": "N599JB",
    "class": "Economy",
    "price": 688
  },
  {
    "FLIGHT_NUMBER": 153,
    "TAIL_NUMBER": "N746JB",
    "class": "Economy",
    "price": 913
  },
  {
    "FLIGHT_NUMBER": 154,
    "TAIL_NUMBER": "N536JB",
    "class": "Economy",
    "price": 679
  },
  {
    "FLIGHT_NUMBER": 155,
    "TAIL_NUMBER": "N484HA",
    "class": "Business",
    "price": 919
  },
  {
    "FLIGHT_NUMBER": 156,
    "TAIL_NUMBER": "N484HA",
    "class": "Economy",
    "price": 716
  },
  {
    "FLIGHT_NUMBER": 157,
    "TAIL_NUMBER": "N762AS",
    "class": "Economy",
    "price": 709
  },
  {
    "FLIGHT_NUMBER": 158,
    "TAIL_NUMBER": "N388SW",
    "class": "Economy",
    "price": 224
  },
  {
    "FLIGHT_NUMBER": 159,
    "TAIL_NUMBER": "N193JB",
    "class": "Economy",
    "price": 724
  },
  {
    "FLIGHT_NUMBER": 160,
    "TAIL_NUMBER": "N3KNAA",
    "class": "Business",
    "price": 340
  },
  {
    "FLIGHT_NUMBER": 161,
    "TAIL_NUMBER": "N905FR",
    "class": "First",
    "price": 396
  },
  {
    "FLIGHT_NUMBER": 162,
    "TAIL_NUMBER": "N792AS",
    "class": "Economy",
    "price": 545
  },
  {
    "FLIGHT_NUMBER": 163,
    "TAIL_NUMBER": "N618NK",
    "class": "First",
    "price": 710
  },
  {
    "FLIGHT_NUMBER": 164,
    "TAIL_NUMBER": "N790AA",
    "class": "Economy",
    "price": 485
  },
  {
    "FLIGHT_NUMBER": 165,
    "TAIL_NUMBER": "N639VA",
    "class": "Economy",
    "price": 816
  },
  {
    "FLIGHT_NUMBER": 166,
    "TAIL_NUMBER": "N565AA",
    "class": "Business",
    "price": 761
  },
  {
    "FLIGHT_NUMBER": 167,
    "TAIL_NUMBER": "N359AA",
    "class": "Economy",
    "price": 933
  },
  {
    "FLIGHT_NUMBER": 168,
    "TAIL_NUMBER": "N629NK",
    "class": "Economy",
    "price": 459
  },
  {
    "FLIGHT_NUMBER": 169,
    "TAIL_NUMBER": "N854AA",
    "class": "Economy",
    "price": 996
  },
  {
    "FLIGHT_NUMBER": 170,
    "TAIL_NUMBER": "N382SW",
    "class": "Economy",
    "price": 613
  },
  {
    "FLIGHT_NUMBER": 171,
    "TAIL_NUMBER": "N934DN",
    "class": "Economy",
    "price": 65
  },
  {
    "FLIGHT_NUMBER": 172,
    "TAIL_NUMBER": "N577AS",
    "class": "Economy",
    "price": 354
  },
  {
    "FLIGHT_NUMBER": 173,
    "TAIL_NUMBER": "N486HA",
    "class": "Business",
    "price": 437
  },
  {
    "FLIGHT_NUMBER": 174,
    "TAIL_NUMBER": "N624VA",
    "class": "Business",
    "price": 779
  },
  {
    "FLIGHT_NUMBER": 175,
    "TAIL_NUMBER": "N3EWAA",
    "class": "First",
    "price": 125
  },
  {
    "FLIGHT_NUMBER": 176,
    "TAIL_NUMBER": "N522NK",
    "class": "Economy",
    "price": 666
  },
  {
    "FLIGHT_NUMBER": 177,
    "TAIL_NUMBER": "N267WN",
    "class": "Economy",
    "price": 855
  },
  {
    "FLIGHT_NUMBER": 178,
    "TAIL_NUMBER": "N485WN",
    "class": "Economy",
    "price": 109
  },
  {
    "FLIGHT_NUMBER": 179,
    "TAIL_NUMBER": "N7738A",
    "class": "Economy",
    "price": 575
  },
  {
    "FLIGHT_NUMBER": 180,
    "TAIL_NUMBER": "N587NK",
    "class": "Business",
    "price": 542
  },
  {
    "FLIGHT_NUMBER": 181,
    "TAIL_NUMBER": "N493HA",
    "class": "Economy",
    "price": 365
  },
  {
    "FLIGHT_NUMBER": 182,
    "TAIL_NUMBER": "N765SW",
    "class": "Economy",
    "price": 536
  },
  {
    "FLIGHT_NUMBER": 183,
    "TAIL_NUMBER": "N521NK",
    "class": "Economy",
    "price": 574
  },
  {
    "FLIGHT_NUMBER": 184,
    "TAIL_NUMBER": "N8603F",
    "class": "Business",
    "price": 782
  },
  {
    "FLIGHT_NUMBER": 185,
    "TAIL_NUMBER": "N334JB",
    "class": "Business",
    "price": 155
  },
  {
    "FLIGHT_NUMBER": 186,
    "TAIL_NUMBER": "N378SW",
    "class": "Business",
    "price": 392
  },
  {
    "FLIGHT_NUMBER": 187,
    "TAIL_NUMBER": "N630VA",
    "class": "Economy",
    "price": 917
  },
  {
    "FLIGHT_NUMBER": 188,
    "TAIL_NUMBER": "N505NK",
    "class": "Economy",
    "price": 726
  },
  {
    "FLIGHT_NUMBER": 189,
    "TAIL_NUMBER": "N391SW",
    "class": "Economy",
    "price": 738
  },
  {
    "FLIGHT_NUMBER": 190,
    "TAIL_NUMBER": "N3FHAA",
    "class": "Economy",
    "price": 185
  },
  {
    "FLIGHT_NUMBER": 191,
    "TAIL_NUMBER": "N925FR",
    "class": "Economy",
    "price": 857
  },
  {
    "FLIGHT_NUMBER": 192,
    "TAIL_NUMBER": "N645JB",
    "class": "Economy",
    "price": 812
  },
  {
    "FLIGHT_NUMBER": 193,
    "TAIL_NUMBER": "N502NK",
    "class": "Economy",
    "price": 909
  },
  {
    "FLIGHT_NUMBER": 194,
    "TAIL_NUMBER": "N939WN",
    "class": "First",
    "price": 253
  },
  {
    "FLIGHT_NUMBER": 195,
    "TAIL_NUMBER": "N69818",
    "class": "First",
    "price": 935
  },
  {
    "FLIGHT_NUMBER": 196,
    "TAIL_NUMBER": "N3FBAA",
    "class": "Economy",
    "price": 360
  },
  {
    "FLIGHT_NUMBER": 197,
    "TAIL_NUMBER": "N633NK",
    "class": "Economy",
    "price": 92
  },
  {
    "FLIGHT_NUMBER": 198,
    "TAIL_NUMBER": "N523JB",
    "class": "Economy",
    "price": 250
  },
  {
    "FLIGHT_NUMBER": 199,
    "TAIL_NUMBER": "N494WN",
    "class": "Business",
    "price": 322
  },
  {
    "FLIGHT_NUMBER": 200,
    "TAIL_NUMBER": "N767AS",
    "class": "Economy",
    "price": 922
  },
  {
    "FLIGHT_NUMBER": 201,
    "TAIL_NUMBER": "N3LJAA",
    "class": "Economy",
    "price": 373
  },
  {
    "FLIGHT_NUMBER": 202,
    "TAIL_NUMBER": "N491HA",
    "class": "Economy",
    "price": 586
  },
  {
    "FLIGHT_NUMBER": 203,
    "TAIL_NUMBER": "N955WN",
    "class": "Business",
    "price": 314
  },
  {
    "FLIGHT_NUMBER": 204,
    "TAIL_NUMBER": "N810UA",
    "class": "Business",
    "price": 451
  },
  {
    "FLIGHT_NUMBER": 205,
    "TAIL_NUMBER": "N484HA",
    "class": "Business",
    "price": 843
  },
  {
    "FLIGHT_NUMBER": 206,
    "TAIL_NUMBER": "N484HA",
    "class": "Economy",
    "price": 300
  },
  {
    "FLIGHT_NUMBER": 207,
    "TAIL_NUMBER": "N446UA",
    "class": "Economy",
    "price": 485
  },
  {
    "FLIGHT_NUMBER": 208,
    "TAIL_NUMBER": "N355AA",
    "class": "Economy",
    "price": 844
  },
  {
    "FLIGHT_NUMBER": 209,
    "TAIL_NUMBER": "N634NK",
    "class": "Economy",
    "price": 229
  },
  {
    "FLIGHT_NUMBER": 210,
    "TAIL_NUMBER": "N830UA",
    "class": "Economy",
    "price": 794
  },
  {
    "FLIGHT_NUMBER": 211,
    "TAIL_NUMBER": "N445UA",
    "class": "Economy",
    "price": 415
  },
  {
    "FLIGHT_NUMBER": 212,
    "TAIL_NUMBER": "N5DHAA",
    "class": "Economy",
    "price": 850
  },
  {
    "FLIGHT_NUMBER": 213,
    "TAIL_NUMBER": "N526JB",
    "class": "First",
    "price": 276
  },
  {
    "FLIGHT_NUMBER": 214,
    "TAIL_NUMBER": "N632NK",
    "class": "First",
    "price": 298
  },
  {
    "FLIGHT_NUMBER": 215,
    "TAIL_NUMBER": "N481HA",
    "class": "Business",
    "price": 659
  },
  {
    "FLIGHT_NUMBER": 216,
    "TAIL_NUMBER": "N816UA",
    "class": "Business",
    "price": 501
  },
  {
    "FLIGHT_NUMBER": 217,
    "TAIL_NUMBER": "N485HA",
    "class": "Economy",
    "price": 545
  },
  {
    "FLIGHT_NUMBER": 218,
    "TAIL_NUMBER": "N485HA",
    "class": "Economy",
    "price": 923
  },
  {
    "FLIGHT_NUMBER": 219,
    "TAIL_NUMBER": "N843VA",
    "class": "Economy",
    "price": 520
  },
  {
    "FLIGHT_NUMBER": 220,
    "TAIL_NUMBER": "N813UA",
    "class": "Economy",
    "price": 842
  },
  {
    "FLIGHT_NUMBER": 221,
    "TAIL_NUMBER": "N197JB",
    "class": "Economy",
    "price": 869
  },
  {
    "FLIGHT_NUMBER": 222,
    "TAIL_NUMBER": "N3JSAA",
    "class": "Economy",
    "price": 655
  },
  {
    "FLIGHT_NUMBER": 223,
    "TAIL_NUMBER": "N816UA",
    "class": "Economy",
    "price": 893
  },
  {
    "FLIGHT_NUMBER": 224,
    "TAIL_NUMBER": "N607NK",
    "class": "First",
    "price": 158
  },
  {
    "FLIGHT_NUMBER": 225,
    "TAIL_NUMBER": "N401UA",
    "class": "First",
    "price": 751
  },
  {
    "FLIGHT_NUMBER": 226,
    "TAIL_NUMBER": "N648JB",
    "class": "Business",
    "price": 927
  },
  {
    "FLIGHT_NUMBER": 227,
    "TAIL_NUMBER": "N571AA",
    "class": "Business",
    "price": 685
  },
  {
    "FLIGHT_NUMBER": 228,
    "TAIL_NUMBER": "N439UA",
    "class": "Economy",
    "price": 249
  },
  {
    "FLIGHT_NUMBER": 229,
    "TAIL_NUMBER": "N428UA",
    "class": "Economy",
    "price": 122
  },
  {
    "FLIGHT_NUMBER": 230,
    "TAIL_NUMBER": "N472UA",
    "class": "Economy",
    "price": 886
  },
  {
    "FLIGHT_NUMBER": 231,
    "TAIL_NUMBER": "N620NK",
    "class": "Economy",
    "price": 430
  },
  {
    "FLIGHT_NUMBER": 232,
    "TAIL_NUMBER": "N796JB",
    "class": "Economy",
    "price": 847
  },
  {
    "FLIGHT_NUMBER": 233,
    "TAIL_NUMBER": "N3BEAA",
    "class": "Economy",
    "price": 367
  },
  {
    "FLIGHT_NUMBER": 234,
    "TAIL_NUMBER": "N838UA",
    "class": "Economy",
    "price": 594
  },
  {
    "FLIGHT_NUMBER": 235,
    "TAIL_NUMBER": "N691WN",
    "class": "First",
    "price": 756
  },
  {
    "FLIGHT_NUMBER": 236,
    "TAIL_NUMBER": "N3HLAA",
    "class": "First",
    "price": 802
  },
  {
    "FLIGHT_NUMBER": 237,
    "TAIL_NUMBER": "N522UA",
    "class": "Economy",
    "price": 818
  },
  {
    "FLIGHT_NUMBER": 238,
    "TAIL_NUMBER": "N995DL",
    "class": "Economy",
    "price": 396
  },
  {
    "FLIGHT_NUMBER": 239,
    "TAIL_NUMBER": "N653SW",
    "class": "Economy",
    "price": 303
  },
  {
    "FLIGHT_NUMBER": 240,
    "TAIL_NUMBER": "N569AS",
    "class": "Economy",
    "price": 128
  },
  {
    "FLIGHT_NUMBER": 241,
    "TAIL_NUMBER": "N429UA",
    "class": "Economy",
    "price": 534
  },
  {
    "FLIGHT_NUMBER": 242,
    "TAIL_NUMBER": "N3DCAA",
    "class": "First",
    "price": 805
  },
  {
    "FLIGHT_NUMBER": 243,
    "TAIL_NUMBER": "N3JRAA",
    "class": "First",
    "price": 571
  },
  {
    "FLIGHT_NUMBER": 244,
    "TAIL_NUMBER": "N319AS",
    "class": "Business",
    "price": 456
  },
  {
    "FLIGHT_NUMBER": 245,
    "TAIL_NUMBER": "N807UA",
    "class": "Business",
    "price": 389
  },
  {
    "FLIGHT_NUMBER": 246,
    "TAIL_NUMBER": "N391DA",
    "class": "Economy",
    "price": 119
  },
  {
    "FLIGHT_NUMBER": 247,
    "TAIL_NUMBER": "N462UA",
    "class": "Economy",
    "price": 695
  },
  {
    "FLIGHT_NUMBER": 248,
    "TAIL_NUMBER": "N640AA",
    "class": "Economy",
    "price": 278
  },
  {
    "FLIGHT_NUMBER": 249,
    "TAIL_NUMBER": "N4WLAA",
    "class": "Economy",
    "price": 159
  },
  {
    "FLIGHT_NUMBER": 250,
    "TAIL_NUMBER": "N468UA",
    "class": "Economy",
    "price": 285
  },
  {
    "FLIGHT_NUMBER": 251,
    "TAIL_NUMBER": "N521SW",
    "class": "Economy",
    "price": 282
  },
  {
    "FLIGHT_NUMBER": 252,
    "TAIL_NUMBER": "N646JB",
    "class": "Economy",
    "price": 611
  },
  {
    "FLIGHT_NUMBER": 253,
    "TAIL_NUMBER": "N378AA",
    "class": "Economy",
    "price": 596
  },
  {
    "FLIGHT_NUMBER": 254,
    "TAIL_NUMBER": "N378AA",
    "class": "Economy",
    "price": 621
  },
  {
    "FLIGHT_NUMBER": 255,
    "TAIL_NUMBER": "N794AA",
    "class": "First",
    "price": 891
  },
  {
    "FLIGHT_NUMBER": 256,
    "TAIL_NUMBER": "N464UA",
    "class": "First",
    "price": 781
  },
  {
    "FLIGHT_NUMBER": 257,
    "TAIL_NUMBER": "N932FR",
    "class": "Business",
    "price": 967
  },
  {
    "FLIGHT_NUMBER": 258,
    "TAIL_NUMBER": "N3HYAA",
    "class": "Business",
    "price": 763
  },
  {
    "FLIGHT_NUMBER": 259,
    "TAIL_NUMBER": "N427UA",
    "class": "Economy",
    "price": 683
  },
  {
    "FLIGHT_NUMBER": 260,
    "TAIL_NUMBER": "N403UA",
    "class": "Economy",
    "price": 490
  },
  {
    "FLIGHT_NUMBER": 261,
    "TAIL_NUMBER": "N952FR",
    "class": "Economy",
    "price": 62
  },
  {
    "FLIGHT_NUMBER": 262,
    "TAIL_NUMBER": "N627JB",
    "class": "Economy",
    "price": 719
  },
  {
    "FLIGHT_NUMBER": 263,
    "TAIL_NUMBER": "N782SA",
    "class": "Economy",
    "price": 999
  },
  {
    "FLIGHT_NUMBER": 264,
    "TAIL_NUMBER": "N839UA",
    "class": "Business",
    "price": 664
  },
  {
    "FLIGHT_NUMBER": 265,
    "TAIL_NUMBER": "N5ECAA",
    "class": "First",
    "price": 731
  },
  {
    "FLIGHT_NUMBER": 266,
    "TAIL_NUMBER": "N5ECAA",
    "class": "Economy",
    "price": 122
  },
  {
    "FLIGHT_NUMBER": 267,
    "TAIL_NUMBER": "N784SW",
    "class": "First",
    "price": 95
  },
  {
    "FLIGHT_NUMBER": 268,
    "TAIL_NUMBER": "N921FR",
    "class": "Economy",
    "price": 598
  },
  {
    "FLIGHT_NUMBER": 269,
    "TAIL_NUMBER": "N834JB",
    "class": "Economy",
    "price": 176
  },
  {
    "FLIGHT_NUMBER": 270,
    "TAIL_NUMBER": "N479UA",
    "class": "Business",
    "price": 326
  },
  {
    "FLIGHT_NUMBER": 271,
    "TAIL_NUMBER": "N556JB",
    "class": "Economy",
    "price": 867
  },
  {
    "FLIGHT_NUMBER": 272,
    "TAIL_NUMBER": "N556JB",
    "class": "Economy",
    "price": 50
  },
  {
    "FLIGHT_NUMBER": 274,
    "TAIL_NUMBER": "N232WN",
    "class": "Economy",
    "price": 112
  },
  {
    "FLIGHT_NUMBER": 275,
    "TAIL_NUMBER": "N598UA",
    "class": "Economy",
    "price": 347
  },
  {
    "FLIGHT_NUMBER": 276,
    "TAIL_NUMBER": "N489HA",
    "class": "Economy",
    "price": 805
  },
  {
    "FLIGHT_NUMBER": 277,
    "TAIL_NUMBER": "N658SW",
    "class": "Economy",
    "price": 389
  },
  {
    "FLIGHT_NUMBER": 278,
    "TAIL_NUMBER": "N826UA",
    "class": "Business",
    "price": 421
  },
  {
    "FLIGHT_NUMBER": 279,
    "TAIL_NUMBER": "N796JB",
    "class": "Business",
    "price": 125
  },
  {
    "FLIGHT_NUMBER": 280,
    "TAIL_NUMBER": "N562JB",
    "class": "First",
    "price": 929
  },
  {
    "FLIGHT_NUMBER": 281,
    "TAIL_NUMBER": "N3FXAA",
    "class": "Economy",
    "price": 495
  },
  {
    "FLIGHT_NUMBER": 282,
    "TAIL_NUMBER": "N821UA",
    "class": "Economy",
    "price": 579
  },
  {
    "FLIGHT_NUMBER": 283,
    "TAIL_NUMBER": "N5DJAA",
    "class": "Economy",
    "price": 227
  },
  {
    "FLIGHT_NUMBER": 284,
    "TAIL_NUMBER": "N832UA",
    "class": "Economy",
    "price": 794
  },
  {
    "FLIGHT_NUMBER": 285,
    "TAIL_NUMBER": "N480HA",
    "class": "Business",
    "price": 574
  },
  {
    "FLIGHT_NUMBER": 286,
    "TAIL_NUMBER": "N480HA",
    "class": "Economy",
    "price": 777
  },
  {
    "FLIGHT_NUMBER": 287,
    "TAIL_NUMBER": "N793JB",
    "class": "Economy",
    "price": 350
  },
  {
    "FLIGHT_NUMBER": 288,
    "TAIL_NUMBER": "N806JB",
    "class": "Economy",
    "price": 479
  },
  {
    "FLIGHT_NUMBER": 289,
    "TAIL_NUMBER": "N373JB",
    "class": "Economy",
    "price": 849
  },
  {
    "FLIGHT_NUMBER": 290,
    "TAIL_NUMBER": "N274JB",
    "class": "Business",
    "price": 887
  },
  {
    "FLIGHT_NUMBER": 291,
    "TAIL_NUMBER": "N492HA",
    "class": "First",
    "price": 697
  },
  {
    "FLIGHT_NUMBER": 292,
    "TAIL_NUMBER": "N951WN",
    "class": "Economy",
    "price": 866
  },
  {
    "FLIGHT_NUMBER": 293,
    "TAIL_NUMBER": "N419WN",
    "class": "First",
    "price": 762
  },
  {
    "FLIGHT_NUMBER": 294,
    "TAIL_NUMBER": "N4YDAA",
    "class": "Economy",
    "price": 100
  },
  {
    "FLIGHT_NUMBER": 295,
    "TAIL_NUMBER": "N202FR",
    "class": "Economy",
    "price": 761
  },
  {
    "FLIGHT_NUMBER": 296,
    "TAIL_NUMBER": "N470UA",
    "class": "Business",
    "price": 303
  },
  {
    "FLIGHT_NUMBER": 297,
    "TAIL_NUMBER": "N544UA",
    "class": "Economy",
    "price": 870
  },
  {
    "FLIGHT_NUMBER": 298,
    "TAIL_NUMBER": "N514NK",
    "class": "Economy",
    "price": 631
  },
  {
    "FLIGHT_NUMBER": 299,
    "TAIL_NUMBER": "N857AA",
    "class": "Economy",
    "price": 335
  },
  {
    "FLIGHT_NUMBER": 300,
    "TAIL_NUMBER": "N818UA",
    "class": "Economy",
    "price": 778
  },
  {
    "FLIGHT_NUMBER": 301,
    "TAIL_NUMBER": "N626NK",
    "class": "Economy",
    "price": 433
  },
  {
    "FLIGHT_NUMBER": 302,
    "TAIL_NUMBER": "N3CMAA",
    "class": "Economy",
    "price": 467
  },
  {
    "FLIGHT_NUMBER": 303,
    "TAIL_NUMBER": "N735SA",
    "class": "Business",
    "price": 862
  },
  {
    "FLIGHT_NUMBER": 304,
    "TAIL_NUMBER": "N607JB",
    "class": "Business",
    "price": 630
  },
  {
    "FLIGHT_NUMBER": 305,
    "TAIL_NUMBER": "N485HA",
    "class": "First",
    "price": 153
  },
  {
    "FLIGHT_NUMBER": 306,
    "TAIL_NUMBER": "N859AA",
    "class": "Economy",
    "price": 493
  },
  {
    "FLIGHT_NUMBER": 307,
    "TAIL_NUMBER": "N488UA",
    "class": "Economy",
    "price": 185
  },
  {
    "FLIGHT_NUMBER": 308,
    "TAIL_NUMBER": "N935FR",
    "class": "Economy",
    "price": 74
  },
  {
    "FLIGHT_NUMBER": 309,
    "TAIL_NUMBER": "N657SW",
    "class": "Economy",
    "price": 740
  },
  {
    "FLIGHT_NUMBER": 310,
    "TAIL_NUMBER": "N201AA",
    "class": "Business",
    "price": 657
  },
  {
    "FLIGHT_NUMBER": 311,
    "TAIL_NUMBER": "N705AS",
    "class": "Economy",
    "price": 154
  },
  {
    "FLIGHT_NUMBER": 312,
    "TAIL_NUMBER": "N833UA",
    "class": "Economy",
    "price": 739
  },
  {
    "FLIGHT_NUMBER": 313,
    "TAIL_NUMBER": "N703AS",
    "class": "Economy",
    "price": 367
  },
  {
    "FLIGHT_NUMBER": 314,
    "TAIL_NUMBER": "N585AA",
    "class": "Business",
    "price": 490
  },
  {
    "FLIGHT_NUMBER": 315,
    "TAIL_NUMBER": "N3MAAA",
    "class": "Business",
    "price": 413
  },
  {
    "FLIGHT_NUMBER": 316,
    "TAIL_NUMBER": "N601NK",
    "class": "Business",
    "price": 311
  },
  {
    "FLIGHT_NUMBER": 317,
    "TAIL_NUMBER": "N222WN",
    "class": "Economy",
    "price": 959
  },
  {
    "FLIGHT_NUMBER": 318,
    "TAIL_NUMBER": "N183JB",
    "class": "Economy",
    "price": 74
  },
  {
    "FLIGHT_NUMBER": 319,
    "TAIL_NUMBER": "N498UA",
    "class": "Economy",
    "price": 547
  },
  {
    "FLIGHT_NUMBER": 320,
    "TAIL_NUMBER": "N622AS",
    "class": "Economy",
    "price": 975
  },
  {
    "FLIGHT_NUMBER": 321,
    "TAIL_NUMBER": "N613AS",
    "class": "Economy",
    "price": 847
  },
  {
    "FLIGHT_NUMBER": 322,
    "TAIL_NUMBER": "N7703A",
    "class": "Economy",
    "price": 465
  },
  {
    "FLIGHT_NUMBER": 323,
    "TAIL_NUMBER": "N520AA",
    "class": "Economy",
    "price": 472
  },
  {
    "FLIGHT_NUMBER": 324,
    "TAIL_NUMBER": "N516UA",
    "class": "First",
    "price": 496
  },
  {
    "FLIGHT_NUMBER": 325,
    "TAIL_NUMBER": "N3LWAA",
    "class": "First",
    "price": 805
  },
  {
    "FLIGHT_NUMBER": 326,
    "TAIL_NUMBER": "N639JB",
    "class": "Economy",
    "price": 78
  },
  {
    "FLIGHT_NUMBER": 327,
    "TAIL_NUMBER": "N692DL",
    "class": "Economy",
    "price": 323
  },
  {
    "FLIGHT_NUMBER": 328,
    "TAIL_NUMBER": "N4XKAA",
    "class": "Economy",
    "price": 326
  },
  {
    "FLIGHT_NUMBER": 329,
    "TAIL_NUMBER": "N568AS",
    "class": "Business",
    "price": 231
  },
  {
    "FLIGHT_NUMBER": 330,
    "TAIL_NUMBER": "N3EWAA",
    "class": "Economy",
    "price": 982
  },
  {
    "FLIGHT_NUMBER": 331,
    "TAIL_NUMBER": "N403UA",
    "class": "Economy",
    "price": 577
  },
  {
    "FLIGHT_NUMBER": 332,
    "TAIL_NUMBER": "N483HA",
    "class": "Economy",
    "price": 102
  },
  {
    "FLIGHT_NUMBER": 333,
    "TAIL_NUMBER": "N918DH",
    "class": "Business",
    "price": 459
  },
  {
    "FLIGHT_NUMBER": 334,
    "TAIL_NUMBER": "N494AA",
    "class": "Business",
    "price": 753
  },
  {
    "FLIGHT_NUMBER": 335,
    "TAIL_NUMBER": "N226WN",
    "class": "Business",
    "price": 903
  },
  {
    "FLIGHT_NUMBER": 336,
    "TAIL_NUMBER": "N490WN",
    "class": "Economy",
    "price": 172
  },
  {
    "FLIGHT_NUMBER": 337,
    "TAIL_NUMBER": "N786AS",
    "class": "Economy",
    "price": 742
  },
  {
    "FLIGHT_NUMBER": 338,
    "TAIL_NUMBER": "N481HA",
    "class": "Economy",
    "price": 376
  },
  {
    "FLIGHT_NUMBER": 339,
    "TAIL_NUMBER": "N576UA",
    "class": "Economy",
    "price": 591
  },
  {
    "FLIGHT_NUMBER": 340,
    "TAIL_NUMBER": "N631VA",
    "class": "Economy",
    "price": 61
  },
  {
    "FLIGHT_NUMBER": 341,
    "TAIL_NUMBER": "N343NB",
    "class": "Economy",
    "price": 121
  },
  {
    "FLIGHT_NUMBER": 342,
    "TAIL_NUMBER": "N440AS",
    "class": "Economy",
    "price": 763
  },
  {
    "FLIGHT_NUMBER": 343,
    "TAIL_NUMBER": "N8649A",
    "class": "First",
    "price": 844
  },
  {
    "FLIGHT_NUMBER": 344,
    "TAIL_NUMBER": "N932FR",
    "class": "First",
    "price": 813
  },
  {
    "FLIGHT_NUMBER": 345,
    "TAIL_NUMBER": "N469AS",
    "class": "Business",
    "price": 999
  },
  {
    "FLIGHT_NUMBER": 346,
    "TAIL_NUMBER": "N454WN",
    "class": "Business",
    "price": 311
  },
  {
    "FLIGHT_NUMBER": 347,
    "TAIL_NUMBER": "N493HA",
    "class": "Economy",
    "price": 567
  },
  {
    "FLIGHT_NUMBER": 348,
    "TAIL_NUMBER": "N203WN",
    "class": "Economy",
    "price": 486
  },
  {
    "FLIGHT_NUMBER": 349,
    "TAIL_NUMBER": "N475HA",
    "class": "Economy",
    "price": 806
  },
  {
    "FLIGHT_NUMBER": 350,
    "TAIL_NUMBER": "N198JB",
    "class": "Economy",
    "price": 63
  },
  {
    "FLIGHT_NUMBER": 351,
    "TAIL_NUMBER": "N3JWAA",
    "class": "Economy",
    "price": 604
  },
  {
    "FLIGHT_NUMBER": 352,
    "TAIL_NUMBER": "N846VA",
    "class": "Economy",
    "price": 984
  },
  {
    "FLIGHT_NUMBER": 353,
    "TAIL_NUMBER": "N570JB",
    "class": "Economy",
    "price": 913
  },
  {
    "FLIGHT_NUMBER": 354,
    "TAIL_NUMBER": "N570JB",
    "class": "First",
    "price": 228
  },
  {
    "FLIGHT_NUMBER": 355,
    "TAIL_NUMBER": "N261WN",
    "class": "First",
    "price": 758
  },
  {
    "FLIGHT_NUMBER": 356,
    "TAIL_NUMBER": "N432UA",
    "class": "Business",
    "price": 267
  },
  {
    "FLIGHT_NUMBER": 357,
    "TAIL_NUMBER": "N465UA",
    "class": "Business",
    "price": 533
  },
  {
    "FLIGHT_NUMBER": 358,
    "TAIL_NUMBER": "N441WN",
    "class": "Economy",
    "price": 897
  },
  {
    "FLIGHT_NUMBER": 359,
    "TAIL_NUMBER": "N901WN",
    "class": "Economy",
    "price": 851
  },
  {
    "FLIGHT_NUMBER": 360,
    "TAIL_NUMBER": "N811UA",
    "class": "Economy",
    "price": 712
  },
  {
    "FLIGHT_NUMBER": 361,
    "TAIL_NUMBER": "N3KTAA",
    "class": "Economy",
    "price": 406
  },
  {
    "FLIGHT_NUMBER": 362,
    "TAIL_NUMBER": "N589JB",
    "class": "Economy",
    "price": 360
  },
  {
    "FLIGHT_NUMBER": 363,
    "TAIL_NUMBER": "N718SW",
    "class": "Economy",
    "price": 581
  },
  {
    "FLIGHT_NUMBER": 364,
    "TAIL_NUMBER": "N547US",
    "class": "Economy",
    "price": 374
  },
  {
    "FLIGHT_NUMBER": 365,
    "TAIL_NUMBER": "N218FR",
    "class": "First",
    "price": 145
  },
  {
    "FLIGHT_NUMBER": 366,
    "TAIL_NUMBER": "N644JB",
    "class": "First",
    "price": 795
  },
  {
    "FLIGHT_NUMBER": 367,
    "TAIL_NUMBER": "N494AA",
    "class": "Economy",
    "price": 449
  },
  {
    "FLIGHT_NUMBER": 368,
    "TAIL_NUMBER": "N480HA",
    "class": "Economy",
    "price": 537
  },
  {
    "FLIGHT_NUMBER": 369,
    "TAIL_NUMBER": "N8312C",
    "class": "Economy",
    "price": 281
  },
  {
    "FLIGHT_NUMBER": 370,
    "TAIL_NUMBER": "N618AS",
    "class": "Economy",
    "price": 982
  },
  {
    "FLIGHT_NUMBER": 371,
    "TAIL_NUMBER": "N3GXAA",
    "class": "Economy",
    "price": 446
  },
  {
    "FLIGHT_NUMBER": 372,
    "TAIL_NUMBER": "N938WN",
    "class": "First",
    "price": 242
  },
  {
    "FLIGHT_NUMBER": 373,
    "TAIL_NUMBER": "N618AS",
    "class": "First",
    "price": 320
  },
  {
    "FLIGHT_NUMBER": 374,
    "TAIL_NUMBER": "N415UA",
    "class": "Business",
    "price": 372
  },
  {
    "FLIGHT_NUMBER": 375,
    "TAIL_NUMBER": "N4WLAA",
    "class": "Business",
    "price": 456
  },
  {
    "FLIGHT_NUMBER": 376,
    "TAIL_NUMBER": "N573AA",
    "class": "Economy",
    "price": 783
  },
  {
    "FLIGHT_NUMBER": 377,
    "TAIL_NUMBER": "N928WN",
    "class": "Economy",
    "price": 729
  },
  {
    "FLIGHT_NUMBER": 378,
    "TAIL_NUMBER": "N3BGAA",
    "class": "Economy",
    "price": 186
  },
  {
    "FLIGHT_NUMBER": 379,
    "TAIL_NUMBER": "N503NK",
    "class": "Economy",
    "price": 770
  },
  {
    "FLIGHT_NUMBER": 380,
    "TAIL_NUMBER": "N760AS",
    "class": "Economy",
    "price": 400
  },
  {
    "FLIGHT_NUMBER": 381,
    "TAIL_NUMBER": "N760AS",
    "class": "Economy",
    "price": 337
  },
  {
    "FLIGHT_NUMBER": 382,
    "TAIL_NUMBER": "N438UA",
    "class": "Economy",
    "price": 681
  },
  {
    "FLIGHT_NUMBER": 383,
    "TAIL_NUMBER": "N622AS",
    "class": "Economy",
    "price": 938
  },
  {
    "FLIGHT_NUMBER": 384,
    "TAIL_NUMBER": "N785SW",
    "class": "Economy",
    "price": 130
  },
  {
    "FLIGHT_NUMBER": 385,
    "TAIL_NUMBER": "N403AA",
    "class": "First",
    "price": 829
  },
  {
    "FLIGHT_NUMBER": 386,
    "TAIL_NUMBER": "N8637A",
    "class": "First",
    "price": 330
  },
  {
    "FLIGHT_NUMBER": 387,
    "TAIL_NUMBER": "N4XXAA",
    "class": "Business",
    "price": 786
  },
  {
    "FLIGHT_NUMBER": 388,
    "TAIL_NUMBER": "N936WN",
    "class": "Business",
    "price": 451
  },
  {
    "FLIGHT_NUMBER": 389,
    "TAIL_NUMBER": "N281JB",
    "class": "Economy",
    "price": 664
  },
  {
    "FLIGHT_NUMBER": 390,
    "TAIL_NUMBER": "N283WN",
    "class": "Economy",
    "price": 120
  },
  {
    "FLIGHT_NUMBER": 391,
    "TAIL_NUMBER": "N706JB",
    "class": "Economy",
    "price": 573
  },
  {
    "FLIGHT_NUMBER": 392,
    "TAIL_NUMBER": "N456UA",
    "class": "Economy",
    "price": 556
  },
  {
    "FLIGHT_NUMBER": 393,
    "TAIL_NUMBER": "N236WN",
    "class": "Business",
    "price": 674
  },
  {
    "FLIGHT_NUMBER": 394,
    "TAIL_NUMBER": "N317JB",
    "class": "Economy",
    "price": 651
  },
  {
    "FLIGHT_NUMBER": 395,
    "TAIL_NUMBER": "N3MCAA",
    "class": "Economy",
    "price": 297
  },
  {
    "FLIGHT_NUMBER": 396,
    "TAIL_NUMBER": "N492HA",
    "class": "Economy",
    "price": 138
  },
  {
    "FLIGHT_NUMBER": 397,
    "TAIL_NUMBER": "N3CGAA",
    "class": "Economy",
    "price": 208
  },
  {
    "FLIGHT_NUMBER": 398,
    "TAIL_NUMBER": "N475WN",
    "class": "Economy",
    "price": 709
  },
  {
    "FLIGHT_NUMBER": 399,
    "TAIL_NUMBER": "N852VA",
    "class": "Economy",
    "price": 100
  },
  {
    "FLIGHT_NUMBER": 400,
    "TAIL_NUMBER": "N381DN",
    "class": "Economy",
    "price": 509
  },
  {
    "FLIGHT_NUMBER": 401,
    "TAIL_NUMBER": "N732US",
    "class": "First",
    "price": 312
  },
  {
    "FLIGHT_NUMBER": 402,
    "TAIL_NUMBER": "N307JB",
    "class": "First",
    "price": 738
  },
  {
    "FLIGHT_NUMBER": 403,
    "TAIL_NUMBER": "N660AW",
    "class": "Economy",
    "price": 448
  },
  {
    "FLIGHT_NUMBER": 404,
    "TAIL_NUMBER": "N621VA",
    "class": "Economy",
    "price": 196
  },
  {
    "FLIGHT_NUMBER": 405,
    "TAIL_NUMBER": "N565AS",
    "class": "Economy",
    "price": 487
  },
  {
    "FLIGHT_NUMBER": 406,
    "TAIL_NUMBER": "N589AS",
    "class": "Economy",
    "price": 336
  },
  {
    "FLIGHT_NUMBER": 407,
    "TAIL_NUMBER": "N845UA",
    "class": "Economy",
    "price": 161
  },
  {
    "FLIGHT_NUMBER": 408,
    "TAIL_NUMBER": "N521UW",
    "class": "First",
    "price": 436
  },
  {
    "FLIGHT_NUMBER": 409,
    "TAIL_NUMBER": "N509NK",
    "class": "First",
    "price": 427
  },
  {
    "FLIGHT_NUMBER": 410,
    "TAIL_NUMBER": "N765US",
    "class": "Business",
    "price": 703
  },
  {
    "FLIGHT_NUMBER": 411,
    "TAIL_NUMBER": "N8614M",
    "class": "Business",
    "price": 942
  },
  {
    "FLIGHT_NUMBER": 412,
    "TAIL_NUMBER": "N904AW",
    "class": "Economy",
    "price": 92
  },
  {
    "FLIGHT_NUMBER": 413,
    "TAIL_NUMBER": "N571UW",
    "class": "Economy",
    "price": 189
  },
  {
    "FLIGHT_NUMBER": 414,
    "TAIL_NUMBER": "N7815L",
    "class": "Economy",
    "price": 569
  },
  {
    "FLIGHT_NUMBER": 415,
    "TAIL_NUMBER": "N509UA",
    "class": "Economy",
    "price": 891
  },
  {
    "FLIGHT_NUMBER": 416,
    "TAIL_NUMBER": "N496UA",
    "class": "Economy",
    "price": 516
  },
  {
    "FLIGHT_NUMBER": 417,
    "TAIL_NUMBER": "N587NK",
    "class": "Economy",
    "price": 647
  },
  {
    "FLIGHT_NUMBER": 418,
    "TAIL_NUMBER": "N706TW",
    "class": "Economy",
    "price": 182
  },
  {
    "FLIGHT_NUMBER": 419,
    "TAIL_NUMBER": "N469UA",
    "class": "Economy",
    "price": 741
  },
  {
    "FLIGHT_NUMBER": 420,
    "TAIL_NUMBER": "N178DN",
    "class": "Economy",
    "price": 900
  },
  {
    "FLIGHT_NUMBER": 421,
    "TAIL_NUMBER": "N967DL",
    "class": "First",
    "price": 618
  },
  {
    "FLIGHT_NUMBER": 422,
    "TAIL_NUMBER": "N847UA",
    "class": "First",
    "price": 802
  },
  {
    "FLIGHT_NUMBER": 423,
    "TAIL_NUMBER": "N713TW",
    "class": "Business",
    "price": 509
  },
  {
    "FLIGHT_NUMBER": 424,
    "TAIL_NUMBER": "N161UW",
    "class": "Business",
    "price": 726
  },
  {
    "FLIGHT_NUMBER": 425,
    "TAIL_NUMBER": "N174US",
    "class": "Economy",
    "price": 430
  },
  {
    "FLIGHT_NUMBER": 426,
    "TAIL_NUMBER": "N848UA",
    "class": "Economy",
    "price": 834
  },
  {
    "FLIGHT_NUMBER": 427,
    "TAIL_NUMBER": "N368JB",
    "class": "Economy",
    "price": 831
  },
  {
    "FLIGHT_NUMBER": 428,
    "TAIL_NUMBER": "N995AT",
    "class": "Economy",
    "price": 973
  },
  {
    "FLIGHT_NUMBER": 429,
    "TAIL_NUMBER": "N939FR",
    "class": "Economy",
    "price": 329
  },
  {
    "FLIGHT_NUMBER": 430,
    "TAIL_NUMBER": "N624AG",
    "class": "Business",
    "price": 115
  },
  {
    "FLIGHT_NUMBER": 431,
    "TAIL_NUMBER": "N810UA",
    "class": "First",
    "price": 117
  },
  {
    "FLIGHT_NUMBER": 432,
    "TAIL_NUMBER": "N908AW",
    "class": "Economy",
    "price": 229
  },
  {
    "FLIGHT_NUMBER": 433,
    "TAIL_NUMBER": "N601AW",
    "class": "First",
    "price": 855
  },
  {
    "FLIGHT_NUMBER": 434,
    "TAIL_NUMBER": "N637JB",
    "class": "Economy",
    "price": 461
  },
  {
    "FLIGHT_NUMBER": 435,
    "TAIL_NUMBER": "N714CB",
    "class": "Economy",
    "price": 882
  },
  {
    "FLIGHT_NUMBER": 436,
    "TAIL_NUMBER": "N703TW",
    "class": "Business",
    "price": 778
  },
  {
    "FLIGHT_NUMBER": 437,
    "TAIL_NUMBER": "N585UW",
    "class": "Economy",
    "price": 269
  },
  {
    "FLIGHT_NUMBER": 438,
    "TAIL_NUMBER": "N465UA",
    "class": "Economy",
    "price": 769
  },
  {
    "FLIGHT_NUMBER": 439,
    "TAIL_NUMBER": "N931FR",
    "class": "Economy",
    "price": 820
  },
  {
    "FLIGHT_NUMBER": 440,
    "TAIL_NUMBER": "N496UA",
    "class": "Economy",
    "price": 843
  },
  {
    "FLIGHT_NUMBER": 441,
    "TAIL_NUMBER": "N808UA",
    "class": "Economy",
    "price": 543
  },
  {
    "FLIGHT_NUMBER": 442,
    "TAIL_NUMBER": "N759GS",
    "class": "Economy",
    "price": 831
  },
  {
    "FLIGHT_NUMBER": 443,
    "TAIL_NUMBER": "N628SW",
    "class": "Business",
    "price": 378
  },
  {
    "FLIGHT_NUMBER": 444,
    "TAIL_NUMBER": "N418UA",
    "class": "Business",
    "price": 387
  },
  {
    "FLIGHT_NUMBER": 445,
    "TAIL_NUMBER": "N579AS",
    "class": "First",
    "price": 613
  },
  {
    "FLIGHT_NUMBER": 446,
    "TAIL_NUMBER": "N651AW",
    "class": "Economy",
    "price": 820
  },
  {
    "FLIGHT_NUMBER": 447,
    "TAIL_NUMBER": "N527JB",
    "class": "Economy",
    "price": 449
  },
  {
    "FLIGHT_NUMBER": 448,
    "TAIL_NUMBER": "N273WN",
    "class": "Economy",
    "price": 925
  },
  {
    "FLIGHT_NUMBER": 449,
    "TAIL_NUMBER": "N447UA",
    "class": "Economy",
    "price": 692
  },
  {
    "FLIGHT_NUMBER": 450,
    "TAIL_NUMBER": "N611SW",
    "class": "Business",
    "price": 712
  },
  {
    "FLIGHT_NUMBER": 451,
    "TAIL_NUMBER": "N633NK",
    "class": "Economy",
    "price": 455
  },
  {
    "FLIGHT_NUMBER": 452,
    "TAIL_NUMBER": "N507AY",
    "class": "Economy",
    "price": 798
  },
  {
    "FLIGHT_NUMBER": 453,
    "TAIL_NUMBER": "N652JB",
    "class": "Economy",
    "price": 188
  },
  {
    "FLIGHT_NUMBER": 454,
    "TAIL_NUMBER": "N442AS",
    "class": "Economy",
    "price": 625
  },
  {
    "FLIGHT_NUMBER": 455,
    "TAIL_NUMBER": "N651AW",
    "class": "Business",
    "price": 371
  },
  {
    "FLIGHT_NUMBER": 456,
    "TAIL_NUMBER": "N830UA",
    "class": "First",
    "price": 330
  },
  {
    "FLIGHT_NUMBER": 457,
    "TAIL_NUMBER": "N585UW",
    "class": "Economy",
    "price": 622
  },
  {
    "FLIGHT_NUMBER": 458,
    "TAIL_NUMBER": "N3758Y",
    "class": "First",
    "price": 333
  },
  {
    "FLIGHT_NUMBER": 459,
    "TAIL_NUMBER": "N536UW",
    "class": "Economy",
    "price": 792
  },
  {
    "FLIGHT_NUMBER": 460,
    "TAIL_NUMBER": "N640AW",
    "class": "Economy",
    "price": 156
  },
  {
    "FLIGHT_NUMBER": 461,
    "TAIL_NUMBER": "N540UW",
    "class": "Business",
    "price": 711
  },
  {
    "FLIGHT_NUMBER": 462,
    "TAIL_NUMBER": "N663JB",
    "class": "Economy",
    "price": 756
  },
  {
    "FLIGHT_NUMBER": 463,
    "TAIL_NUMBER": "N482UA",
    "class": "Economy",
    "price": 663
  },
  {
    "FLIGHT_NUMBER": 464,
    "TAIL_NUMBER": "N434UA",
    "class": "Economy",
    "price": 467
  },
  {
    "FLIGHT_NUMBER": 465,
    "TAIL_NUMBER": "N828JB",
    "class": "Economy",
    "price": 149
  },
  {
    "FLIGHT_NUMBER": 466,
    "TAIL_NUMBER": "N309AS",
    "class": "Economy",
    "price": 723
  },
  {
    "FLIGHT_NUMBER": 467,
    "TAIL_NUMBER": "N404WN",
    "class": "Economy",
    "price": 422
  },
  {
    "FLIGHT_NUMBER": 469,
    "TAIL_NUMBER": "N506NK",
    "class": "Business",
    "price": 893
  },
  {
    "FLIGHT_NUMBER": 470,
    "TAIL_NUMBER": "N534NK",
    "class": "Business",
    "price": 626
  },
  {
    "FLIGHT_NUMBER": 471,
    "TAIL_NUMBER": "N197UW",
    "class": "First",
    "price": 545
  },
  {
    "FLIGHT_NUMBER": 472,
    "TAIL_NUMBER": "N712TW",
    "class": "Economy",
    "price": 616
  },
  {
    "FLIGHT_NUMBER": 473,
    "TAIL_NUMBER": "N423WN",
    "class": "Economy",
    "price": 981
  },
  {
    "FLIGHT_NUMBER": 474,
    "TAIL_NUMBER": "N614SW",
    "class": "Economy",
    "price": 730
  },
  {
    "FLIGHT_NUMBER": 475,
    "TAIL_NUMBER": "N599JB",
    "class": "Economy",
    "price": 477
  },
  {
    "FLIGHT_NUMBER": 476,
    "TAIL_NUMBER": "N196DN",
    "class": "Business",
    "price": 729
  },
  {
    "FLIGHT_NUMBER": 477,
    "TAIL_NUMBER": "N453AS",
    "class": "Economy",
    "price": 251
  },
  {
    "FLIGHT_NUMBER": 478,
    "TAIL_NUMBER": "N528NK",
    "class": "Economy",
    "price": 999
  },
  {
    "FLIGHT_NUMBER": 479,
    "TAIL_NUMBER": "N476UA",
    "class": "Economy",
    "price": 790
  },
  {
    "FLIGHT_NUMBER": 480,
    "TAIL_NUMBER": "N676AW",
    "class": "Business",
    "price": 136
  },
  {
    "FLIGHT_NUMBER": 481,
    "TAIL_NUMBER": "N323AS",
    "class": "Business",
    "price": 773
  },
  {
    "FLIGHT_NUMBER": 482,
    "TAIL_NUMBER": "N433AS",
    "class": "Business",
    "price": 282
  },
  {
    "FLIGHT_NUMBER": 483,
    "TAIL_NUMBER": "N705JB",
    "class": "Economy",
    "price": 64
  },
  {
    "FLIGHT_NUMBER": 484,
    "TAIL_NUMBER": "N809UA",
    "class": "Economy",
    "price": 722
  },
  {
    "FLIGHT_NUMBER": 485,
    "TAIL_NUMBER": "N910DE",
    "class": "Economy",
    "price": 285
  },
  {
    "FLIGHT_NUMBER": 486,
    "TAIL_NUMBER": "N629VA",
    "class": "Economy",
    "price": 889
  },
  {
    "FLIGHT_NUMBER": 487,
    "TAIL_NUMBER": "N150UW",
    "class": "Economy",
    "price": 723
  },
  {
    "FLIGHT_NUMBER": 488,
    "TAIL_NUMBER": "N269WN",
    "class": "Economy",
    "price": 644
  },
  {
    "FLIGHT_NUMBER": 489,
    "TAIL_NUMBER": "N653AW",
    "class": "Economy",
    "price": 361
  },
  {
    "FLIGHT_NUMBER": 490,
    "TAIL_NUMBER": "N662AW",
    "class": "First",
    "price": 851
  },
  {
    "FLIGHT_NUMBER": 491,
    "TAIL_NUMBER": "N478UA",
    "class": "First",
    "price": 830
  },
  {
    "FLIGHT_NUMBER": 492,
    "TAIL_NUMBER": "N232WN",
    "class": "Economy",
    "price": 509
  },
  {
    "FLIGHT_NUMBER": 493,
    "TAIL_NUMBER": "N836AW",
    "class": "Economy",
    "price": 315
  },
  {
    "FLIGHT_NUMBER": 494,
    "TAIL_NUMBER": "N738CB",
    "class": "Economy",
    "price": 335
  },
  {
    "FLIGHT_NUMBER": 495,
    "TAIL_NUMBER": "N548UA",
    "class": "Business",
    "price": 554
  },
  {
    "FLIGHT_NUMBER": 496,
    "TAIL_NUMBER": "N436UA",
    "class": "Economy",
    "price": 970
  },
  {
    "FLIGHT_NUMBER": 497,
    "TAIL_NUMBER": "N476UA",
    "class": "Economy",
    "price": 181
  },
  {
    "FLIGHT_NUMBER": 498,
    "TAIL_NUMBER": "N702TW",
    "class": "Economy",
    "price": 308
  },
  {
    "FLIGHT_NUMBER": 499,
    "TAIL_NUMBER": "N551AS",
    "class": "Business",
    "price": 66
  },
  {
    "FLIGHT_NUMBER": 500,
    "TAIL_NUMBER": "N844UA",
    "class": "Business",
    "price": 195
  }
]

result = flights.insert_many(flightdata)

# %%
pprint.pprint(flights.find_one( {"class" : "First"} ))
# Out:
# {'FLIGHT_NUMBER': 3,
#  'TAIL_NUMBER': 'N913JB',
#  '_id': ObjectId('642218bee2cfcf45a6dff8d3'),
#  'class': 'First',
#  'price': 891}
